# %%
import xarray as xr
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
files = "C:/Users/maggi/ANL_Internship_2023/FD70_Rain_Gauge/FD70_data/*.nc"

# %%
ds = xr.open_mfdataset(files)
# Out:
# C:\Users\maggi\anaconda3\lib\site-packages\xarray\core\indexing.py:1227: PerformanceWarning: Slicing is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array[indexer]
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array[indexer]
#   return self.array[key]

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:                 (time: 3784770, mean_diameter: 41)
# Coordinates:
#   * time                    (time) datetime64[ns] 2023-02-28T22:59:18 ... 202...
#   * mean_diameter           (mean_diameter) float64 0.12 0.14 0.17 ... 6.73 7.0
# Data variables: (12/20)
#     status                  (time) object dask.array<chunksize=(3642,), meta=np.ndarray>
#     mor_1_minute            (time) float64 dask.array<chunksize=(3642,), meta=np.ndarray>
#     mor_10_minute           (time) float64 dask.array<chunksize=(3642,), meta=np.ndarray>
#     current_precip0         (time) object dask.array<chunksize=(3642,), meta=np.ndarray>
#     current_precip1         (time) object dask.array<chunksize=(3642,), meta=np.ndarray>
#     current_precip2         (time) object dask.array<chunksize=(3642,), meta=np.ndarray>
#     ...                      ...
#     relative_humidity       (time) float64 dask.array<chunksize=(3642,), meta=np.ndarray>
# ...

# %%
precip = ds['precip_accumulation']

# %%
precip.plot()
plt.title('FD70 Accumulated Precipitation')
plt.xlabel('Date')
plt.ylabel('Total Precipitation (mm)')
plt.show()

# %% [markdown]
# ### Disclaimer:
#
# This is sus.
